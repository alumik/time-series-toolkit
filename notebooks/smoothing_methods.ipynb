# %%
# %load_ext autoreload
# %autoreload 2

import seaborn as sns

import tskit

sns.set_style('darkgrid')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
ts_random_walk = tskit.generators.random_walk(length=100)
tskit.plot(ts_random_walk)

# %%
tskit.smoothing.ma(ts_random_walk, window=5).plot()

# %%
tskit.smoothing.ewma(ts_random_walk, alpha=0.3).plot()

# %%
tskit.smoothing.median(ts_random_walk, window=5).plot()

# %%
tskit.smoothing.savgol(ts_random_walk, window=5, order=1).plot()
