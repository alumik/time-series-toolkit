# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import seaborn as sns

import tskit

sns.set_style('darkgrid')

# %% [markdown]
# # tskit.data

# %% [markdown]
# ## tskit.data.TimeSeries

# %% [markdown]
# ### tskit.data.TimeSeries.__init__()

# %% [markdown]
# Create a new TimeSeries object from integer index values.

# %%
tskit.TimeSeries(
    index=[0, 2, 7],
    values=[0, 1, 2],
).plot()
# Out:
# D:\Projects\lang-python\time-series-toolkit\tskit\plot.py:103: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# Create a new TimeSeries object from `pd.DateTimeIndex` values.

# %%
import datetime

tskit.TimeSeries(
    index=pd.DatetimeIndex([
        datetime.datetime(2000, 1, 3),
        datetime.datetime(2000, 1, 1),
        datetime.datetime(2000, 1, 4),
    ]),
    values=[0, 1, 2],
    name='foo',
).plot()

# %% [markdown]
# ### tskit.data.TimeSeries.from_generators()

# %%
tskit.TimeSeries.from_generators(
        generators=['sine', 'random_walk'],
        generator_args=[{'amplitude': 0.5}, {}],
        weights=[1.0, 0.5],
        standardize_idx=[1],
        length=100,
).plot()

# %% [markdown]
# ### tskit.data.TimeSeries.from_config()

# %%
tskit.TimeSeries.from_config({
        'generators': [
            {
                'name': 'sine',
                'weight': 1.0,
                'args': {
                    'amplitude': 0.5,
                },
            },
            {
                'name': 'random_walk',
                'weight': 0.5,
                'standardize': True,
            },
        ],
        'length': 100,
    }).plot()
# Out:
# D:\Projects\lang-python\time-series-toolkit\tskit\plot.py:103: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# ### tskit.data.TimeSeries.to_shapelet()

# %% [markdown]
# See `tskit.transform.to_shapelet()` for more details.

# %% [markdown]
# ### tskit.data.TimeSeries.add_noise()

# %% [markdown]
# See `tskit.noise` for more details.
