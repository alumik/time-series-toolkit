# %%
# %load_ext autoreload
# %autoreload 2

import seaborn as sns

import tskit

sns.set_style('darkgrid')

# %%
ts_random_walk = tskit.generator.random_walk(length=100)
tskit.plot(ts_random_walk)
# Out:
# D:\Projects\lang-python\time-series-toolkit\tskit\plot.py:28: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
ts_sine = tskit.generator.sine(length=100)
tskit.plot(ts_sine)

# %%
ts_cosine = tskit.generator.cosine(length=100)
tskit.plot(ts_cosine)

# %%
ts_linear = tskit.generator.linear(length=100)
tskit.plot(ts_linear)

# %%
ts_gaussian = tskit.generator.gaussian(length=100)
tskit.plot(ts_gaussian)

# %%
ts_uniform = tskit.generator.uniform(length=100)
tskit.plot(ts_uniform)

# %%
ts_step = tskit.generator.step(length=100, step_size=10, delta=10)
tskit.plot(ts_step)

# %%
ts_exponential = tskit.generator.exponential(length=100)
tskit.plot(ts_exponential)

# %%
ts_poisson = tskit.generator.poisson(length=100)
tskit.plot(ts_poisson)

# %%
ts_log_normal = tskit.generator.log_normal(length=100)
tskit.plot(ts_log_normal)

# %%
ts_gamma = tskit.generator.gamma(length=100)
tskit.plot(ts_gamma)

# %%
ts_square = tskit.generator.square(length=100, period=10)
tskit.plot(ts_square)

# %%
ts_sawtooth = tskit.generator.sawtooth(length=100, period=10)
tskit.plot(ts_sawtooth)

# %%
ts_triangle = tskit.generator.triangle(length=100, period=10)
tskit.plot(ts_triangle)

# %%
ts_impulse = tskit.generator.impulse(length=100, impulse_time=[12, 67, 32])
tskit.plot(ts_impulse)

# %%
ts_perlin = tskit.generator.perlin(length=100, factor_x=0.3, factor_pi=0.3, factor_e=0.3)
tskit.plot(ts_perlin)
